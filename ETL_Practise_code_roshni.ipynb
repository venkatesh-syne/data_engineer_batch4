# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime

# %%
# Configuration 

customers_df = pd.read_csv(r"C:\Users\roshn\Documents\Data_Engineer\Python_Learning\Functions\customers.csv")

products_df = pd.read_excel(r"C:\Users\roshn\Documents\Data_Engineer\Python_Learning\Functions\products.xlsx")

orders_df = pd.read_json(r"C:\Users\roshn\Documents\Data_Engineer\Python_Learning\Functions\orders.json")

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
# Logging

import logging


logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(message)s"
)

# %%
customers_df.drop_duplicates(
    subset=["customer_id"],
    inplace=True
)

products_df.drop_duplicates(
    subset=["product_id"],
    inplace=True
)

orders_df.drop_duplicates(
    subset=["order_id"],
    inplace=True
)

customers_df.fillna(
    {
        "name": "UNKNOWN",
        "city": "UNKNOWN"
    },
    inplace=True
)

products_df.fillna(
    {
        "price": 0
    },
    inplace=True
)

orders_df.fillna(
    {
        "quantity": 0
    },
    inplace=True
)
# Out:
#      order_id  customer_id  product_id  quantity  order_date
# 0           1          476         380         1  2025-06-15
# 1           2          279        1034         5  2025-09-01
# 2           3          942         674         1  2025-10-12
# 3           4          423         933         4  2025-02-01
# 4           5          730         263         5  2025-10-23
# ..        ...          ...         ...       ...         ...
# 995       996          539         642         2  2025-10-01
# 996       997          852         716         3  2025-08-03
# 997       998          178         576         2  2025-03-03
# 998       999          229         331         2  2025-05-01
# 999      1000          957        1060         1  2025-09-10
#
# [1000 rows x 5 columns]

# %%
sales_df = pd.merge(
    orders_df,
    customers_df,
    on="customer_id",
    how="left"
)
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     1000 non-null   int64
#  1   customer_id  1000 non-null   int64
#  2   product_id   1000 non-null   int64
#  3   quantity     1000 non-null   int64
#  4   order_date   1000 non-null   str
#  5   name         1000 non-null   str
#  6   city         1000 non-null   str
# dtypes: int64(4), str(3)
# memory usage: 82.0 KB

# %%
sales_df = pd.merge(
    sales_df,
    products_df,
    on="product_id",
    how="left"
)
sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      1000 non-null   int64
#  1   customer_id   1000 non-null   int64
#  2   product_id    1000 non-null   int64
#  3   quantity      1000 non-null   int64
#  4   order_date    1000 non-null   str
#  5   name          1000 non-null   str
#  6   city          1000 non-null   str
#  7   product_name  1000 non-null   str
#  8   price         1000 non-null   int64
# dtypes: int64(5), str(4)
# memory usage: 110.4 KB

# %%
sales_df["sales_amount"] = (
    sales_df["quantity"]
    * sales_df["price"]
)

sales_df["name"] = (
    sales_df["name"]
    .str.upper()
)

sales_df["load_timestamp"] = (
    datetime.now()
)

sales_df["order_date"] = pd.to_datetime(
    sales_df["order_date"]
)

sales_df["year"] = (
    sales_df["order_date"]
    .dt.year
)

sales_df["month"] = (
    sales_df["order_date"]
    .dt.month
)

# %%
print("\nNull Count")

print(
    sales_df.isnull().sum()
)

print("\nDuplicate Count")

print(
    sales_df.duplicated().sum()
)
# Out:
# Null Count
# order_id          0
# customer_id       0
# product_id        0
# quantity          0
# order_date        0
# name              0
# city              0
# product_name      0
# price             0
# sales_amount      0
# load_timestamp    0
# year              0
# month             0
# dtype: int64
#
# Duplicate Count
# 0

# %%
summary_df = (
    sales_df
    .groupby(
        ["customer_id", "name"]
    )["sales_amount"]
    .sum()
    .reset_index()
)

print(summary_df.head())
# Out:
#    customer_id          name  sales_amount
# 0            2    PRIYA BHAT        417058
# 1            3  ANJALI REDDY        392408
# 2            4   ROHIT VERMA          8735
# 3            6    AMIT MEHTA        129707
# 4            8  NITIN MISHRA         59830

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pandas pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyarrow
sales_df.to_parquet(
    r"C:\Users\roshn\Documents\Data_Engineer\Python_Learning\Functions\sales_data.parquet",
    engine="pyarrow",
    index=False
)

print("Parquet file created successfully!")
# Out:
# Parquet file created successfully!

# %%
# MYSQL CONNECTION
import urllib


password = urllib.parse.quote_plus("Stellantis@2015")

# 2. Build the connection engine using your specific details
engine = create_engine(
    f"mysql+pymysql://root:{password}@localhost/practisedb"
)

# 3. Test the connection
with engine.connect() as conn:
    print("Connected Successfully")
# Out:
# Connected Successfully

# %%
print(type(customers_df))
print(customers_df.shape)
print(customers_df.head())
# Out:
# <class 'pandas.DataFrame'>
# (1000, 3)
#    customer_id          name       city
# 0            1  Rohit Mishra       Pune
# 1            2    Priya Bhat  Hyderabad
# 2            3  Anjali Reddy    Chennai
# 3            4   Rohit Verma       Pune
# 4            5   Kiran Yadav  Bengaluru

# %%
print(type(engine))
# Out:
# <class 'sqlalchemy.engine.base.Engine'>

# %%
with engine.connect() as conn:
    print("Connected")
# Out:
# Connected

# %%
import pandas as pd
import sqlalchemy

print(pd.__version__)
print(sqlalchemy.__version__)
# Out:
# 3.0.3
# 2.0.51

# %%
customers_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1000 non-null   int64
#  1   name         1000 non-null   str
#  2   city         1000 non-null   str
# dtypes: int64(1), str(2)
# memory usage: 40.8 KB

# %%
customers_df.to_sql(
    name="customers",
    con=engine,
    if_exists="replace",
    index=False
)


# LOAD PRODUCTS


products_df.to_sql(
    name="products",
    con=engine,
    if_exists="replace",
    index=False
)


# LOAD ORDERS


orders_df.to_sql(
    name="orders",
    con=engine,
    if_exists="replace",
    index=False
)


# LOAD SALES


sales_df.to_sql(
    name="sales",
    con=engine,
    if_exists="replace",
    index=False
)


# LOAD SUMMARY


summary_df.to_sql(
    name="customer_sales_summary",
    con=engine,
    if_exists="replace",
    index=False
)

print(
    "Data loaded successfully"
)


# VERIFY MYSQL DATA


mysql_df = pd.read_sql(
    "SELECT * FROM sales LIMIT 5",
    engine
)

print(mysql_df)

print(
    "\nETL COMPLETED SUCCESSFULLY"
)
# Out:
# Data loaded successfully
#    order_id  customer_id  product_id  quantity order_date           name  \
# 0         1          476         380         1 2025-06-15   ANJALI REDDY
# 1         2          279        1034         5 2025-09-01      MANOJ RAO
# 2         3          942         674         1 2025-10-12    KIRAN VERMA
# 3         4          423         933         4 2025-02-01    ARJUN JOSHI
# 4         5          730         263         5 2025-10-23  VIKRAM MISHRA
#
#         city      product_name  price  sales_amount      load_timestamp  year  \
# 0      Delhi       HP Keyboard  42965         42965 2026-06-16 10:19:24  2025
# 1      Surat         Lenovo TV  49275        246375 2026-06-16 10:19:24  2025
# 2    Kolkata     Xiaomi Tablet  22981         22981 2026-06-16 10:19:24  2025
# 3  Bengaluru   Xiaomi Keyboard  23029         92116 2026-06-16 10:19:24  2025
# 4     Indore  Samsung Keyboard  10662         53310 2026-06-16 10:19:24  2025
#
#    month
# 0      6
# 1      9
# ...
