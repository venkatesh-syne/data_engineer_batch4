# %%
import pandas as pd
from random import randint

# %%
columns = ['a', 'b', 'c']

# %%
df = pd.DataFrame(columns=columns)

# %%
for i in range(5):
    df.loc[i] = [randint(-1,1) for n in range(3)]

# %%
df
# Out:
#    a  b  c
# 0  0  0  1
# 1 -1 -1 -1
# 2 -1  1 -1
# 3  1  1 -1
# 4  1  0  1
