# %%
import pandas as pd
df = pd.DataFrame([['AA', "temp", 1],['BB', "temp", 2],['CC', "temp", 3]], columns = ['name','temp', 'value'])

# %%
df
# Out:
#   name  temp  value
# 0   AA  temp      1
# 1   BB  temp      2
# 2   CC  temp      3

# %%
df = df[["name","temp"]]

# %%
df
# Out:
#   name  temp
# 0   AA  temp
# 1   BB  temp
# 2   CC  temp
