# %%
import pandas as pd
df = pd.DataFrame([['AA', 1],['BB', 2],['CC', 3]], columns = ['name','value'])
# Out:
# Running cells with '.venv (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Venkatesh/Practice/Pandas/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df

# %%
df = pd.DataFrame([['AA', 1],['BB', 2],['CC', 3]], columns = ['name','value'])

# %%
values = df.pop('value')

# %%
df

# %%
values
