# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(0,10,size=(10, 4)), columns=list('ABCD'))

# %%
df
# Out:
#    A  B  C  D
# 0  0  2  6  6
# 1  8  2  1  5
# 2  8  2  0  6
# 3  5  5  2  8
# 4  8  8  4  6
# 5  3  1  2  9
# 6  7  0  8  7
# 7  6  2  3  9
# 8  3  7  1  8
# 9  6  8  3  8
